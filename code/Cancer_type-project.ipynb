# %%
# !pip install -U ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 38.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.8 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=fe27d1471df51bfae91baf55a05bc8fe54e8a43f1ca62c9d0ac1ce10b16ca587
#   Stored in directory: /root/.cache/pip/wheels/5f/d4/d7/4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
# ...

# %%
# !pip install pydicom
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 18.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/MAIA projects/Microproyecto 4 semestre/
# Out:
# /content/drive/MyDrive/Colab Notebooks/MAIA projects/Microproyecto 4 semestre

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/MAIA projects/Microproyecto 4 semestre'

# %%
import pydicom
import matplotlib.pyplot as plt
import os

# Ruta a la carpeta de la serie
folder_path = "./data/TCGA-VS-A8EB/05-05-2004-NA-RESSONANCIA MAGNETICA DE ABDOME INFERIOR-20151/301.000000-AXI T2 ssSH 5MM-79572"

# Leer todos los archivos DICOM y ordenarlos por posición de corte
dicoms = [pydicom.dcmread(os.path.join(folder_path, f))
          for f in os.listdir(folder_path) if f.endswith(".dcm")]
dicoms.sort(key=lambda x: float(x.ImagePositionPatient[2]))  # Orden por eje Z

# Mostrar el corte central
mid_slice = dicoms[len(dicoms)//2]
plt.imshow(mid_slice.pixel_array, cmap='gray')
plt.title(mid_slice.SeriesDescription)
plt.axis('off')
plt.show()

# %%
import pandas as pd

# %%
clinical_data= pd.read_csv("./data/cesc_tcga_gdc_clinical_data.tsv", sep="\t")

# %%
clinical_data.head()
# Out:
#         Study ID    Patient ID        Sample ID  Diagnosis Age Biopsy Site  \
# 0  cesc_tcga_gdc  TCGA-2W-A8YY  TCGA-2W-A8YY-01           51.0    Cervical
# 1  cesc_tcga_gdc  TCGA-4J-AA1J  TCGA-4J-AA1J-01           31.0    Cervical
# 2  cesc_tcga_gdc  TCGA-BI-A0VR  TCGA-BI-A0VR-01           53.0    Cervical
# 3  cesc_tcga_gdc  TCGA-BI-A0VS  TCGA-BI-A0VS-01           48.0    Cervical
# 4  cesc_tcga_gdc  TCGA-BI-A20A  TCGA-BI-A20A-01           49.0    Cervical
#
#                         Cancer Type              Cancer Type Detailed  \
# 0  Cervical Squamous Cell Carcinoma  Cervical Squamous Cell Carcinoma
# 1  Cervical Squamous Cell Carcinoma  Cervical Squamous Cell Carcinoma
# 2  Cervical Squamous Cell Carcinoma  Cervical Squamous Cell Carcinoma
# 3  Cervical Squamous Cell Carcinoma  Cervical Squamous Cell Carcinoma
# 4  Cervical Squamous Cell Carcinoma  Cervical Squamous Cell Carcinoma
#
#    Last Communication Contact from Initial Pathologic Diagnosis Date  \
# ...

# %%
clinical_data.value_counts('Disease Type')
# Out:
# Disease Type
# Cervical Squamous Cell Carcinoma                 255
# Endocervical Type of Adenocarcinoma               21
# Mucinous Adenocarcinoma of Endocervical Type      17
# Adenosquamous                                      7
# Endocervical Adenocarcinoma of the Usual Type      6
# Endometrioid Adenocarcinoma of Endocervix          3
# Name: count, dtype: int64

# %%
clinical_data.columns
# Out:
# Index(['Study ID', 'Patient ID', 'Sample ID', 'Diagnosis Age', 'Biopsy Site',
#        'Cancer Type', 'Cancer Type Detailed',
#        'Last Communication Contact from Initial Pathologic Diagnosis Date',
#        'Birth from Initial Pathologic Diagnosis Date',
#        'Death from Initial Pathologic Diagnosis Date', 'Disease Free (Months)',
#        'Disease Free Status', 'Disease Type', 'Ethnicity Category',
#        'FIGO Stage', 'Fraction Genome Altered', 'ICD-10 Classification',
#        'Is FFPE', 'Morphology', 'Mutation Count', 'Oncotree Code',
#        'Overall Survival (Months)', 'Overall Survival Status',
#        'Other Patient ID', 'Other Sample ID', 'AJCC Pathologic M-Stage',
#        'AJCC Pathologic N-Stage', 'AJCC Pathologic T-Stage',
#        'Primary Diagnosis', 'Patient Primary Tumor Site', 'Prior Malignancy',
#        'Prior Treatment', 'Project Identifier', 'Project Name',
#        'Project State', 'Race Category', 'Number of Samples Per Patient',
# ...

# %%
names = ['TCGA-VS-A8Q9', 'TCGA-VS-A8QA', 'TCGA-VS-A8QC', 'TCGA-VS-A8QF', 'TCGA-VS-A8QH', 'TCGA-VS-A8QM', 'TCGA-VS-A94W', 'TCGA-VS-A94X', 'TCGA-VS-A94Y', 'TCGA-VS-A94Z', 'TCGA-VS-A950', 'TCGA-VS-A952', 'TCGA-VS-A953', 'TCGA-VS-A954', 'TCGA-VS-A957', 'TCGA-VS-A958', 'TCGA-VS-A959', 'LICENSE', 'TCGA-VS-A8EB', 'TCGA-VS-A8EC', 'TCGA-VS-A8EG', 'TCGA-VS-A8EH', 'TCGA-VS-A8EI', 'TCGA-VS-A8EJ', 'TCGA-VS-A8EK', 'TCGA-VS-A8EL', 'TCGA-VS-A8Q8', 'TCGA-VS-A9U5', 'TCGA-VS-A9U6', 'TCGA-VS-A9U7', 'TCGA-VS-A9UA', 'TCGA-VS-A9UB', 'TCGA-VS-A9UC', 'TCGA-VS-A9UD', 'TCGA-VS-A9UH', 'TCGA-VS-A9UI', 'TCGA-VS-A9UJ', 'TCGA-VS-A9UL', 'TCGA-VS-A9UM', 'TCGA-VS-A9UO', 'TCGA-VS-A9UP', 'TCGA-VS-A9UQ', 'TCGA-VS-A9UR', 'TCGA-VS-A9UT', 'TCGA-VS-A9UU', 'TCGA-VS-A9UV', 'TCGA-VS-A9UY', 'TCGA-VS-A9UZ', 'TCGA-VS-A9V0', 'TCGA-VS-A9V1', 'TCGA-VS-A9V2', 'TCGA-VS-A9V3', 'TCGA-VS-A9V4', 'TCGA-VS-A9V5', 'TCGA-VS-AA62']

# %%
df_filtrado = clinical_data[clinical_data["Patient ID"].isin(names)]

# %%
# Imagenes de resonancia magnetica de 54 pacientes
df_filtrado.shape
# Out:
# (54, 43)

# %%
df_filtrado.head()
# Out:
#           Study ID    Patient ID        Sample ID  Diagnosis Age Biopsy Site  \
# 236  cesc_tcga_gdc  TCGA-VS-A8EB  TCGA-VS-A8EB-01           41.0    Cervical
# 237  cesc_tcga_gdc  TCGA-VS-A8EC  TCGA-VS-A8EC-01           55.0    Cervical
# 238  cesc_tcga_gdc  TCGA-VS-A8EG  TCGA-VS-A8EG-01           36.0    Cervical
# 239  cesc_tcga_gdc  TCGA-VS-A8EH  TCGA-VS-A8EH-01           56.0    Cervical
# 240  cesc_tcga_gdc  TCGA-VS-A8EI  TCGA-VS-A8EI-01           38.0    Cervical
#
#                           Cancer Type              Cancer Type Detailed  \
# 236  Cervical Squamous Cell Carcinoma  Cervical Squamous Cell Carcinoma
# 237  Cervical Squamous Cell Carcinoma  Cervical Squamous Cell Carcinoma
# 238  Cervical Squamous Cell Carcinoma  Cervical Squamous Cell Carcinoma
# 239  Cervical Squamous Cell Carcinoma  Cervical Squamous Cell Carcinoma
# 240  Cervical Squamous Cell Carcinoma  Cervical Squamous Cell Carcinoma
#
# ...

# %%
df_filtrado.value_counts('Disease Type')
# Out:
# Disease Type
# Cervical Squamous Cell Carcinoma                42
# Mucinous Adenocarcinoma of Endocervical Type    12
# Name: count, dtype: int64

# %%
# from ydata_profiling import ProfileReport

# # Data Exploration
# ProfileReport(df_filtrado)
